# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Data Analytics and ML\The Lannister Data Chronicles_ Decrypting Diabetes.csv')

# %%
df = pd.DataFrame(data)
df.head()
# Out:
#    Diabetes_012  HighBP  HighChol  CholCheck  BMI  Smoker  Stroke  \
# 0             0       1         1          1   40       1       0
# 1             0       0         0          0   25       1       0
# 2             0       1         1          1   28       0       0
# 3             0       1         0          1   27       0       0
# 4             0       1         1          1   24       0       0
#
#    HeartDiseaseorAttack  PhysActivity  Fruits  ...  AnyHealthcare  \
# 0                     0             0       0  ...              1
# 1                     0             1       0  ...              0
# 2                     0             0       1  ...              1
# 3                     0             1       1  ...              1
# 4                     0             1       1  ...              1
#
#    NoDocbcCost  GenHlth  MentHlth  PhysHlth  DiffWalk  Sex  Age  Education  \
# 0            0        5        18        15         1    0    9          4
# ...

# %%
df['Diabetes_012'].value_counts()
# Out:
# Diabetes_012
# 0    213703
# 2     35346
# 1      4631
# Name: count, dtype: int64

# %% [markdown]
# """
# GenHlth
# HighBP
# BMI
# DiffWalk
# Age
# HighChol
# HeartDiseaseorAttack
# PhysHlth
# Income
# Education
# """

# %% [markdown]
# Visualisation of numeric data for diabetes = 1

# %%
numeric_df = df['Diabetes_012']==1
numeric_df = df[['Age', 'BMI', 'GenHlth', 'PhysHlth', 'Education', 'Income']]
numeric_df.head()
# Out:
#    Age  BMI  GenHlth  PhysHlth  Education  Income
# 0    9   40        5        15          4       3
# 1    7   25        3         0          6       1
# 2    9   28        5        30          4       8
# 3   11   27        2         0          3       6
# 4   11   24        2         0          5       4

# %%
numeric_df.shape
# Out:
# (253680, 6)

# %%
plt.hist(numeric_df['Age'])
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Distribution of Age')
plt.savefig('./Images/Hist-Age.png')
plt.show()

# %%
plt.hist(numeric_df['BMI'])
plt.xlabel('BMI')
plt.ylabel('Count')
plt.title('Distribution of BMI')
plt.savefig('./Images/Hist-BMI.png')
plt.show()

# %%
plt.hist(numeric_df['PhysHlth'])
plt.xlabel('Physical health')
plt.ylabel('Count')
plt.title('Distribution of Physical health')
plt.savefig('./Images/Physical-Health.png')
plt.show()

# %%
plt.hist(numeric_df['GenHlth'])
plt.xlabel('General health')
plt.ylabel('Count')
plt.title('Distribution of General health')
plt.savefig('./Images/General-Health.png')
plt.show()

# %%
plt.hist(numeric_df['Education'], color='salmon')
plt.xlabel('Education')
plt.ylabel('Count')
plt.title('Distribution of Education')
plt.savefig('./Images/Education.png')
plt.show()

# %%
plt.hist(numeric_df['Income'], color='green')
plt.xlabel('Income')
plt.ylabel('Count')
plt.title('Distribution of Income')
plt.savefig('./Images/Income.png')
plt.show()
